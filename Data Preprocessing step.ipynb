# %% [markdown]
# # Data Preprocessing Steps

# %% [markdown]
# 1. Reading Data
# 2. Exploring Data / Data Insight
# 3. Cleansing Data
# 4. Outlier Detection and Removing
# 5. Data Transformation (Normalize Data / Rescale Data)
# 6. Categorical into Numerical
# 7. Dimensionality Reduction(PCA)
# 8. Handling Imbalanced Data
# 9. Feature Selection
# 10. Data Splitting

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

import numpy as np 
import pandas as pd

# %% [markdown]
# # 1: Reading Data

# %%
data = pd.read_csv('weather_forecast_data.csv')

data.head()
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain

# %%
data.head(2)
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain

# %%
data.head(30)
# Out:
#     Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0     23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1     27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2     25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3     23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4     20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# 5     26.147353  48.217260   15.258547    59.766279  1049.738751  no rain
# 6     20.939680  40.799444    2.232566    45.827508  1014.173766  no rain
# 7     32.294325  51.848471    2.873621    92.551497  1006.041733  no rain
# 8     34.091569  48.057114    5.570206    82.524873   993.732047  no rain
# 9     19.586038  82.978293    5.760537    98.014450  1036.503457     rain
# 10    29.793126  81.317651   16.926099    93.923294  1029.402690  no rain
# 11    23.222373  76.877943   15.825673    72.869790   980.108934     rain
# 12    24.201114  45.146538   11.572713     5.253042  1033.985867  no rain
# 13    33.139916  90.326477    5.771774    99.910178   987.803792  no rain
# 14    11.775901  96.960009    6.377567    47.331870  1046.404288  no rain
# 15    12.178232  67.212407   11.844365     6.099704  1003.291526  no rain
# 16    10.505460  75.456091   14.797331    99.142331  1011.577194     rain
# 17    30.815496  65.048447    7.681961    57.037672   980.348663  no rain
# 18    29.453919  49.849040   10.191241    45.900402  1037.707488  no rain
# 19    31.750304  50.030332   17.760663     1.978943  1001.571778  no rain
# 20    34.465459  51.939437   12.995817    42.840117  1018.951281  no rain
# 21    29.978964  43.359500   10.711003    18.327075  1044.862056  no rain
# 22    21.536984  93.134654    1.424449    71.894899   990.935567     rain
# 23    29.513229  90.087869    3.520304     0.786690  1040.713073  no rain
# 24    12.956861  62.314755    4.019832    53.303568  1015.016725  no rain
# 25    25.998026  55.707599   12.462966     4.371622  1044.711932  no rain
# 26    13.583832  95.735485    2.162255    71.483000  1037.564854     rain
# 27    33.616723  45.566143    0.579897    95.301949  1011.008602  no rain
# 28    23.046208  68.747937    7.207011     4.332055   986.209824  no rain
# 29    20.366548  33.814871   14.377184    10.308416   982.113822  no rain

# %%
data.tail()
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain

# %%
data.shape
# Out:
# (2500, 6)

# %%
data.tail(20)
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 2480    10.426018  94.715288    6.303279    47.831657  1018.434880  no rain
# 2481    23.976170  77.144515   16.145567    84.636004  1010.286784     rain
# 2482    22.780079  46.163250    4.999574    54.831934   983.214289  no rain
# 2483    29.847710  87.348236    3.295808    99.137103  1016.720300  no rain
# 2484    20.588745  59.436831    3.810290    90.471117  1033.728861  no rain
# 2485    23.836261  78.863261   19.713528    38.562791  1034.098247  no rain
# 2486    28.550233  64.044753    8.266152    95.548263  1031.376699  no rain
# 2487    32.428647  95.860543    7.919347    76.534181   994.238794  no rain
# 2488    19.500864  34.786267   15.140360    52.550272   985.124592  no rain
# 2489    25.040837  40.905769    1.254794    99.104320   991.833351  no rain
# 2490    27.365273  43.619778    3.390757    69.498333   980.694046  no rain
# 2491    11.081767  45.470035   14.397602    19.460689  1032.905052  no rain
# 2492    30.019013  46.479933    6.393025    11.403676   994.319633  no rain
# 2493    19.435755  40.699514   14.033566    26.211576  1010.480761  no rain
# 2494    26.755974  78.504229    0.457207    73.550223   986.482791  no rain
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain

# %%
data.sample()
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover   Pressure     Rain
# 2394     22.37429  55.569146   17.002149    78.018866  986.64326  no rain

# %%
data.sample(30)
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 190     19.955527  60.406758    9.688374    15.115048  1010.225379  no rain
# 558     25.582367  58.995474    7.982725    25.880761   986.920933  no rain
# 1161    13.899448  93.307803   14.676800    19.776114   981.804602  no rain
# 1639    30.045397  52.307065    1.397568     1.561165   994.663003  no rain
# 724     19.814220  42.061653   13.255745    64.424194  1048.217524  no rain
# 2338    19.152939  58.022902   19.245551    49.930824  1000.738625  no rain
# 1319    34.855827  57.379500   13.135618    41.144604  1042.184002  no rain
# 1062    10.132751  87.960026    1.530296    24.800406  1023.544295  no rain
# 1017    16.091947  88.517520    7.073849    27.258801   993.577243  no rain
# 960     15.502597  65.243519   12.123845    96.680249  1008.480384  no rain
# 1050    16.640814  52.748047    6.073898    27.628549  1021.192839  no rain
# 1405    32.803774  53.019726    6.480561    26.443398  1043.358441  no rain
# 313     12.240076  52.918798    2.557150    81.299896   998.234452  no rain
# 1764    12.105282  93.630943   14.198437    87.361301  1012.925985     rain
# 2085    27.616616  61.020686    4.571101    67.094047   990.063975  no rain
# 1123    12.763057  37.473731   12.547940     0.025384  1049.867602  no rain
# 1694    14.079543  79.961843   14.370756    34.223629  1009.284922  no rain
# 295     15.607926  78.600404   14.141451    87.658257  1013.963044     rain
# 272     18.453974  49.641298   19.232660    75.876349  1016.780722  no rain
# 139     20.785461  35.381110   18.107263    88.094192  1006.690162  no rain
# 2333    14.756513  32.089364   16.536149    86.799985   995.885615  no rain
# 2455    20.664285  41.821836   10.150651    15.044623  1029.761740  no rain
# 777     22.348946  75.388959   10.117921    25.964937  1010.066263  no rain
# 1827    23.891566  43.267130   19.504545    70.080013  1024.067597  no rain
# 1784    29.166733  40.097383   12.189087    47.593336   984.246944  no rain
# 250     18.890318  51.643428    0.226645    77.885552  1026.365218  no rain
# 976     23.372705  87.214648   11.892037    36.971966  1025.316767  no rain
# 1632    11.069078  89.683583    5.804538    23.905690   992.303157  no rain
# 1704    17.754887  44.935971    1.787142    83.951837  1012.636418  no rain
# 1294    10.619226  32.810852   16.924988    79.125241  1011.754684  no rain

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2500 non-null   float64
#  1   Humidity     2500 non-null   float64
#  2   Wind_Speed   2500 non-null   float64
#  3   Cloud_Cover  2500 non-null   float64
#  4   Pressure     2500 non-null   float64
#  5   Rain         2500 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 117.3+ KB

# %%
data.describe()
# Out:
#        Temperature     Humidity   Wind_Speed  Cloud_Cover     Pressure
# count  2500.000000  2500.000000  2500.000000  2500.000000  2500.000000
# mean     22.581725    64.347094     9.906255    49.658104  1014.312336
# std       7.326996    19.954739     5.780316    29.123104    20.196433
# min      10.001842    30.005071     0.009819     0.015038   980.014486
# 25%      16.359398    47.339815     4.761909    23.900016   996.938630
# 50%      22.536448    63.920797     9.908572    49.488284  1013.433035
# 75%      28.976476    81.561021    14.948408    75.324140  1031.735067
# max      34.995214    99.997481    19.999132    99.997795  1049.985593

# %% [markdown]
# # 2: Data Cleaning

# %%
data.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Pressure       0
# Rain           0
# dtype: int64

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
numeric_cols = data.select_dtypes(include=[np.number])

nm = pd.DataFrame(numeric_cols)
nm.head(2)
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759
# 1    27.879734  46.489704    5.952484     4.990053   992.614190

# %%
non_numeric_cols = data.select_dtypes(exclude=[np.number])
non_nm = pd.DataFrame(non_numeric_cols)
non_nm.head(2)
# Out:
#       Rain
# 0     rain
# 1  no rain

# %%
non_nm.Rain
# Out:
# 0          rain
# 1       no rain
# 2       no rain
# 3          rain
# 4       no rain
#          ...
# 2495    no rain
# 2496    no rain
# 2497    no rain
# 2498    no rain
# 2499    no rain
# Name: Rain, Length: 2500, dtype: object

# %%
import pandas as pd
import numpy as np


numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])


numeric_cols.fillna(numeric_cols.mean(), inplace=True)   



data1 = pd.concat([numeric_cols, non_numeric_cols], axis=1)


missing_values = data1.isnull().sum()
print(missing_values)
# Out:
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Pressure       0
# Rain           0
# dtype: int64

# %%
data.shape
# Out:
# (2500, 6)

# %% [markdown]
# Removal: Deleting rows with missing values.
# -

# %%
data = pd.read_csv('weather_forecast_data.csv')
data.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Pressure       0
# Rain           0
# dtype: int64

# %%
data.shape
# Out:
# (2500, 6)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.dropna(inplace=True)


missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Pressure       0
# Rain           0
# dtype: int64

# %%
data.shape
# Out:
# (2500, 6)

# %% [markdown]
# Removing Duplicates
# -

# %%
data = pd.read_csv('weather_forecast_data.csv')
data.shape
# Out:
# (2500, 6)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (2500, 6)

# %% [markdown]
# # 3: Outlier Detection and Removal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('weather_forecast_data.csv')



data.describe()
# Out:
#        Temperature     Humidity   Wind_Speed  Cloud_Cover     Pressure
# count  2500.000000  2500.000000  2500.000000  2500.000000  2500.000000
# mean     22.581725    64.347094     9.906255    49.658104  1014.312336
# std       7.326996    19.954739     5.780316    29.123104    20.196433
# min      10.001842    30.005071     0.009819     0.015038   980.014486
# 25%      16.359398    47.339815     4.761909    23.900016   996.938630
# 50%      22.536448    63.920797     9.908572    49.488284  1013.433035
# 75%      28.976476    81.561021    14.948408    75.324140  1031.735067
# max      34.995214    99.997481    19.999132    99.997795  1049.985593

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %%
numeric_cols = data.select_dtypes(include=[np.number])


Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1



data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]


plt.figure(figsize=(20, 6))


plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))


plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (2500, 6)

# %%
data_cleaned.head()
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain

# %% [markdown]
# # 4. Data Transformation

# %% [markdown]
# Key Differences
# -
# Range of Values:
#
# Normalization: Values are scaled to a fixed range, typically [0, 1].
# Standardization: Values are rescaled to have a mean of 0 and a standard deviation of 1.
# Effect on Distribution:
#
# Normalization: Compresses or stretches the data to fit within the specified range, potentially altering the original distribution.
# Standardization: Preserves the shape of the original distribution but changes the scale.
# Use Cases:
#
# Normalization: Suitable for distance-based algorithms, like k-nearest neighbors and neural networks.
# Standardization: Suitable for algorithms that assume a normal distribution, like linear regression and logistic regression.

# %% [markdown]
# Normalization/Standardization
# -
# - Normalization
# Definition:
# Normalization rescales the data to a fixed range, typically [0, 1] or [-1, 1].

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler


data = pd.read_csv('weather_forecast_data.csv')


numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])


scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)


scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)


scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)


print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (2500, 6)
#
# ************************************************************
#    Temperature  Humidity  Wind_Speed  Cloud_Cover  Pressure     Rain
# 0     0.548885  0.851343    0.366485     0.504954  0.748370     rain
# 1     0.715305  0.235520    0.297292     0.049759  0.180070  no rain
# 2     0.602850  0.758193    0.068145     0.148433  0.388977  no rain
# 3     0.544954  0.633821    0.352225     0.672518  0.037409     rain
# 4     0.423693  0.955157    0.231829     0.476696  0.011586  no rain

# %% [markdown]
# Standardization
# -
# Definition:
# Standardization rescales the data so that it has a mean of 0 and a standard deviation of 1.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('weather_forecast_data.csv')


numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])


scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)


scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)


scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)


print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (2500, 6)
#
# ************************************************************
#    Temperature  Humidity  Wind_Speed  Cloud_Cover  Pressure     Rain
# 0     0.155431  1.265393   -0.444814     0.028972  0.894714     rain
# 1     0.723225 -0.895074   -0.684143    -1.534074 -1.074570  no rain
# 2     0.339547  0.938599   -1.476731    -1.195246 -0.350663  no rain
# 3     0.142018  0.502270   -0.494138     0.604355 -1.568924     rain
# 4    -0.271701  1.629599   -0.910571    -0.068058 -1.658406  no rain

# %% [markdown]
# # 5: One-Hot Encoding

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('weather_forecast_data.csv')
data.head(2)
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain

# %%
data["Pressure"].unique()
# Out:
# array([1032.37875869,  992.61418951, 1007.23162012, ...,  999.11918658,
#        1046.50187474, 1001.72917591])

# %%
data.Temperature.unique()
# Out:
# array([23.7203376 , 27.87973416, 25.0690844 , ..., 28.10827448,
#        14.78927534, 26.55435586])

# %%
data.Temperature.unique()
# Out:
# array([23.7203376 , 27.87973416, 25.0690844 , ..., 28.10827448,
#        14.78927534, 26.55435586])

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('weather_forecast_data.csv')


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']


data1 = pd.get_dummies(cat_features)
data1
# Out:
#    Rain
# 0  True

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rain    1 non-null      bool
# dtypes: bool(1)
# memory usage: 133.0 bytes

# %%
cat_features
# Out:
# ['Rain']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('weather_forecast_data.csv')


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']


data1 = pd.get_dummies(data, columns=cat_features)


scaled_data = pd.concat([data, data1], axis=1)


print(scaled_data.shape)
print()
print('*' * 70)

scaled_data.head()
# Out:
# (2500, 13)
#
# **********************************************************************
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain  \
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain
#
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure  Rain_no rain  \
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759         False
# 1    27.879734  46.489704    5.952484     4.990053   992.614190          True
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620          True
# 3    23.622080  74.367758    7.050551    67.255282   982.632013         False
# 4    20.591370  96.858822    4.643921    47.676444   980.825142          True
#
#    Rain_rain
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False

# %%
data.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind_Speed', 'Cloud_Cover', 'Pressure',
#        'Rain'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind_Speed', 'Cloud_Cover', 'Pressure',
#        'Rain', 'Temperature', 'Humidity', 'Wind_Speed', 'Cloud_Cover',
#        'Pressure', 'Rain_no rain', 'Rain_rain'],
#       dtype='object')

# %%
data1.head()
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure  Rain_no rain  \
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759         False
# 1    27.879734  46.489704    5.952484     4.990053   992.614190          True
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620          True
# 3    23.622080  74.367758    7.050551    67.255282   982.632013         False
# 4    20.591370  96.858822    4.643921    47.676444   980.825142          True
#
#    Rain_rain
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False

# %% [markdown]
# # 6: Data Reduction

# %% [markdown]
# Dimensionality Reduction
# -
# PCA (Principal Component Analysis)

# %%
scaled_data.shape
# Out:
# (2500, 13)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


data = pd.read_csv('weather_forecast_data.csv')


data.fillna(data.mean(numeric_only=True), inplace=True)


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']


data = pd.get_dummies(data, columns=cat_features)


scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)


n_features = data_scaled.shape[1]


n_components = min(15, n_features)
pca_full = PCA(n_components=n_components)
data_pca_full = pca_full.fit_transform(data_scaled)


pca_2d = PCA(n_components=2)
data_pca_2d = pca_2d.fit_transform(data_scaled)


print("PCA shape (max 15 or feature count):", data_pca_full.shape)
print(data_pca_full[:5])


plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[numeric_features[0]], data[numeric_features[1]], alpha=0.5)
plt.title('Original Data')
plt.xlabel(numeric_features[0])
plt.ylabel(numeric_features[1])

plt.subplot(1, 2, 2)
plt.scatter(data_pca_2d[:, 0], data_pca_2d[:, 1], alpha=0.5)
plt.title('PCA Transformed Data (2D)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
# Out:
# PCA shape (max 15 or feature count): (2500, 7)
# [[ 3.65079070e+00  4.23762737e-02  2.40131406e-01 -9.53136396e-03
#   -1.39046639e+00  1.10767300e+00 -2.01599061e-16]
#  [-1.36095751e+00 -1.32601370e+00  1.30306246e-01  3.44624531e-01
#    1.56799889e-01  1.34787976e+00  2.47167896e-15]
#  [-5.71826051e-01 -1.62927950e+00  3.68993727e-01  6.26854013e-01
#   -1.22474601e+00 -7.21953946e-02 -5.75594246e-17]
#  [ 3.54959340e+00 -1.24620272e+00  8.28888575e-01 -2.07093267e-01
#    8.20657757e-01  1.30801099e+00  7.11287905e-17]
#  [ 1.02350387e-01 -2.20713024e+00  3.65396603e-01 -1.33797144e-03
#    2.47056110e-02 -1.25887055e+00  4.91173710e-16]]

# %% [markdown]
# # 7: Handling Imbalanced Data
#
# - Resampling Techniques
# - Oversampling

# %%
data = pd.read_csv('weather_forecast_data.csv')

data.Temperature.value_counts(True)
# Out:
# Temperature
# 23.720338    0.0004
# 31.279962    0.0004
# 20.720244    0.0004
# 23.879847    0.0004
# 20.423349    0.0004
#               ...
# 25.936557    0.0004
# 30.298464    0.0004
# 21.984614    0.0004
# 32.871577    0.0004
# 26.554356    0.0004
# Name: proportion, Length: 2500, dtype: float64

# %%
data.shape
# Out:
# (2500, 6)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt


data = pd.read_csv('weather_forecast_data.csv')


data.fillna(data.mean(numeric_only=True), inplace=True)


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']


data = pd.get_dummies(data, columns=cat_features)


scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)



if data['Pressure'].dtype != 'int64' and data['Pressure'].dtype != 'bool':
   
    
    data['Pressure'] = (data['Pressure'] > 0.5).astype(int)


X = data.drop(columns=['Pressure'])  
y = data['Pressure']  


if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)


smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)


data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['Pressure'])], axis=1)
data_resampled.head()
# Out:
# (2500, 6) (2500,)
#    Temperature  Humidity  Wind_Speed  Cloud_Cover  Rain_no rain  Rain_rain  \
# 0     0.155431  1.265393   -0.444814     0.028972         False       True
# 1     0.723225 -0.895074   -0.684143    -1.534074          True      False
# 2     0.339547  0.938599   -1.476731    -1.195246          True      False
# 3     0.142018  0.502270   -0.494138     0.604355         False       True
# 4    -0.271701  1.629599   -0.910571    -0.068058          True      False
#
#    Pressure
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
data_resampled.Pressure.value_counts(True)
# Out:
# Pressure
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
data_resampled.shape
# Out:
# (3228, 7)

# %% [markdown]
# Undersampling
# -

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt


data = pd.read_csv('weather_forecast_data.csv')


data.fillna(data.mean(numeric_only=True), inplace=True)


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']


data = pd.get_dummies(data, columns=cat_features)


scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)



if data['Pressure'].dtype != 'int64' and data['Pressure'].dtype != 'bool':
    
    
    data['Pressure'] = (data['Pressure'] > 0.5).astype(int)


X = data.drop(columns=['Pressure'])  
y = data['Pressure']  


if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)


from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)


data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['Pressure'])], axis=1)
data_resampled.head()
# Out:
# (2500, 6) (2500,)
#       Temperature  Humidity  Wind_Speed  Cloud_Cover  Rain_no rain  Rain_rain  \
# 2346    -1.232957  0.010741    0.473059     0.179175          True      False
# 2380    -1.297139 -1.105305   -0.893804    -1.479041          True      False
# 1390    -1.143695 -1.498102    1.497983     0.528029          True      False
# 1544    -0.075853 -1.193056    0.856646     0.679749          True      False
# 872      0.100333 -1.383864    0.645460    -1.441497          True      False
#
#       Pressure
# 2346         0
# 2380         0
# 1390         0
# 1544         0
# 872          0

# %%
data_resampled.Pressure.value_counts()
# Out:
# Pressure
# 0    886
# 1    886
# Name: count, dtype: int64

# %%
data_resampled.shape
# Out:
# (1772, 7)

# %% [markdown]
# # 7: Splitting Data

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('weather_forecast_data.csv')

X = data.drop('Pressure', axis=1)
y = data['Pressure']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1750, 5), (750, 5), (1750,), (750,))
